# %%
import pandas as pd

# %%
df = pd.read_csv('CricketTestMatch.csv')

# %%
df.head()
# Out:
#              Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF  \
# 0  DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94  9800+
# 1    HC Brook (ENG)  2022-2023   12    20   1  1181   186  62.15   1287
# 2    AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667
# 3   RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
# 4   GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83   416+
#
#       SR  100  50  0   4s  6s
# 0  58.60   29  13  7  626   6
# 1  91.76    4   7  1  141  23
# 2  55.68    5   4  2  186   5
# 3  54.48    7  11  1  246  11
# 4  56.00   10   5  2  104   1

# %%
df.shape
# Out:
# (66, 15)

# %%
df.dtypes
# Out:
# Player     object
# Span       object
# Mat         int64
# Inns        int64
# NO          int64
# Runs        int64
# HS         object
# Ave       float64
# BF         object
# SR        float64
# 100         int64
# 50          int64
# 0           int64
# 4s          int64
# 6s          int64
# dtype: object

# %%
df
# Out:
#                Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF  \
# 0    DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94  9800+
# 1      HC Brook (ENG)  2022-2023   12    20   1  1181   186  62.15   1287
# 2      AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667
# 3     RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
# 4     GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83   416+
# ..                ...        ...  ...   ...  ..   ...   ...    ...    ...
# 61   KD Walters (AUS)  1965-1981   74   125  14  5357   250  48.26  8662+
# 62  GC Smith (ICC/SA)  2002-2014  117   205  13  9265   277  48.25  15525
# 63  WH Ponsford (AUS)  1924-1934   29    48   4  2122   266  48.22  3118+
# 64    SJ McCabe (AUS)  1930-1938   39    62   5  2748   232  48.21  3217+
# 65   DR Jardine (ENG)  1928-1934   22    33   6  1296   127  48.00  2110+
#
#        SR  100  50   0    4s  6s
# 0   58.60   29  13   7   626   6
# ...

# %%
#Rename columns

# %%
df = df.rename(columns = {'Player': 'player_name', 'span': 'playing_span', 'Mat':'matches_played', 'Inns':'innings_batted','NO':'not_outs','Runs': 'runs','HS':'highest_innings_score','Ave':'batting_average','BF':'balls_faced','SR':'batting_strike_rate','100':'hundereds_scored','50':'fifties_scored','0':'ducks_scored','4s':'boundary_fours','6s':'boundary_sixes'})

# %%
df
# Out:
#           player_name       Span  matches_played  innings_batted  not_outs  \
# 0    DG Bradman (AUS)  1928-1948              52              80        10
# 1      HC Brook (ENG)  2022-2023              12              20         1
# 2      AC Voges (AUS)  2015-2016              20              31         7
# 3     RG Pollock (SA)  1963-1970              23              41         4
# 4     GA Headley (WI)  1930-1954              22              40         4
# ..                ...        ...             ...             ...       ...
# 61   KD Walters (AUS)  1965-1981              74             125        14
# 62  GC Smith (ICC/SA)  2002-2014             117             205        13
# 63  WH Ponsford (AUS)  1924-1934              29              48         4
# 64    SJ McCabe (AUS)  1930-1938              39              62         5
# 65   DR Jardine (ENG)  1928-1934              22              33         6
#
#     runs highest_innings_score  batting_average balls_faced  \
# ...

# %%
df.isnull().any()
# Out:
# player_name              False
# Span                     False
# matches_played           False
# innings_batted           False
# not_outs                 False
# runs                     False
# highest_innings_score    False
# batting_average          False
# balls_faced               True
# batting_strike_rate      False
# hundereds_scored         False
# fifties_scored           False
# ducks_scored             False
# boundary_fours           False
# boundary_sixes           False
# dtype: bool

# %%
df[df['balls_faced'].isna()==1]
# Out:
#              player_name       Span  matches_played  innings_batted  not_outs  \
# 9         ED Weekes (WI)  1948-1958              48              81         5
# 16       CL Walcott (WI)  1948-1960              44              74         7
# 58  Hon.FS Jackson (ENG)  1893-1905              20              33         4
#
#     runs highest_innings_score  batting_average balls_faced  \
# 9   4455                   207            58.61         NaN
# 16  3798                   220            56.68         NaN
# 58  1415                  144*            48.79         NaN
#
#     batting_strike_rate  hundereds_scored  fifties_scored  ducks_scored  \
# 9                   0.0                15              19             6
# 16                  0.0                15              14             1
# 58                  0.0                 5               6             3
#
#     boundary_fours  boundary_sixes
# 9              258               2
# 16             107              11
# ...

# %%
df['balls_faced'] = df['balls_faced'].fillna(0)

# %%
df[df['balls_faced'].isna()==1]
# Out:
# Empty DataFrame
# Columns: [player_name, Span, matches_played, innings_batted, not_outs, runs, highest_innings_score, batting_average, balls_faced, batting_strike_rate, hundereds_scored, fifties_scored, ducks_scored, boundary_fours, boundary_sixes]
# Index: []

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 61    False
# 62    False
# 63    False
# 64    False
# 65    False
# Length: 66, dtype: bool

# %%
df[df['player_name'].duplicated()==1]
# Out:
#            player_name       Span  matches_played  innings_batted  not_outs  \
# 5      GA Headley (WI)  1930-1955              22              40         4
# 15      JB Hobbs (ENG)  1908-1931              61             102         7
# 36  S Chanderpaul (WI)  1994-2016             164             280        49
# 54       V Kohli (IND)  2011-2025             113             191        11
#
#      runs highest_innings_score  batting_average balls_faced  \
# 5    2190                  270*            61.83        416+
# 15   5410                   212            57.94       5363+
# 36  11867                  203*            52.37       27396
# 54   8848                  254*            50.15       15925
#
#     batting_strike_rate  hundereds_scored  fifties_scored  ducks_scored  \
# 5                 56.00                10               5             2
# 15                46.22                15              28             4
# ...

# %%
df[df['player_name'].isin(['GA Headley (WI)','JB Hobbs (ENG)','Chanderpaul (WI)','V Kohli (IND)'])]
# Out:
#         player_name       Span  matches_played  innings_batted  not_outs  \
# 4   GA Headley (WI)  1930-1954              22              40         4
# 5   GA Headley (WI)  1930-1955              22              40         4
# 14   JB Hobbs (ENG)  1908-1930              61             102         7
# 15   JB Hobbs (ENG)  1908-1931              61             102         7
# 53    V Kohli (IND)  2011-2024             113             191        11
# 54    V Kohli (IND)  2011-2025             113             191        11
#
#     runs highest_innings_score  batting_average balls_faced  \
# 4   2190                  270*            60.83        416+
# 5   2190                  270*            61.83        416+
# 14  5410                   211            56.94       5363+
# 15  5410                   212            57.94       5363+
# 53  8848                  254*            49.15       15924
# 54  8848                  254*            50.15       15925
#
# ...

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.head()
# Out:
#         player_name       Span  matches_played  innings_batted  not_outs  \
# 0  DG Bradman (AUS)  1928-1948              52              80        10
# 1    HC Brook (ENG)  2022-2023              12              20         1
# 2    AC Voges (AUS)  2015-2016              20              31         7
# 3   RG Pollock (SA)  1963-1970              23              41         4
# 4   GA Headley (WI)  1930-1954              22              40         4
#
#    runs highest_innings_score  batting_average balls_faced  \
# 0  6996                   334            99.94       9800+
# 1  1181                   186            62.15        1287
# 2  1485                  269*            61.87        2667
# 3  2256                   274            60.97       1707+
# 4  2190                  270*            60.83        416+
#
#    batting_strike_rate  hundereds_scored  fifties_scored  ducks_scored  \
# 0                58.60                29              13             7
# ...

# %%
df['Span'].str.split(pat = '-')
# Out:
# 0     [1928, 1948]
# 1     [2022, 2023]
# 2     [2015, 2016]
# 3     [1963, 1970]
# 4     [1930, 1954]
#           ...
# 61    [1965, 1981]
# 62    [2002, 2014]
# 63    [1924, 1934]
# 64    [1930, 1938]
# 65    [1928, 1934]
# Name: Span, Length: 66, dtype: object

# %%
df['launch_year'] = df['Span'].str.split(pat = '-').str[0]

# %%
df['final_year'] = df['Span'].str.split(pat = '-').str[1]

# %%
df.head()
# Out:
#         player_name       Span  matches_played  innings_batted  not_outs  \
# 0  DG Bradman (AUS)  1928-1948              52              80        10
# 1    HC Brook (ENG)  2022-2023              12              20         1
# 2    AC Voges (AUS)  2015-2016              20              31         7
# 3   RG Pollock (SA)  1963-1970              23              41         4
# 4   GA Headley (WI)  1930-1954              22              40         4
#
#    runs highest_innings_score  batting_average balls_faced  \
# 0  6996                   334            99.94       9800+
# 1  1181                   186            62.15        1287
# 2  1485                  269*            61.87        2667
# 3  2256                   274            60.97       1707+
# 4  2190                  270*            60.83        416+
#
#    batting_strike_rate  hundereds_scored  fifties_scored  ducks_scored  \
# 0                58.60                29              13             7
# ...

# %%
df = df.drop(['Span'], axis = 1)

# %%
df.head()
# Out:
#         player_name  matches_played  innings_batted  not_outs  runs  \
# 0  DG Bradman (AUS)              52              80        10  6996
# 1    HC Brook (ENG)              12              20         1  1181
# 2    AC Voges (AUS)              20              31         7  1485
# 3   RG Pollock (SA)              23              41         4  2256
# 4   GA Headley (WI)              22              40         4  2190
#
#   highest_innings_score  batting_average balls_faced  batting_strike_rate  \
# 0                   334            99.94       9800+                58.60
# 1                   186            62.15        1287                91.76
# 2                  269*            61.87        2667                55.68
# 3                   274            60.97       1707+                54.48
# 4                  270*            60.83        416+                56.00
#
#    hundereds_scored  fifties_scored  ducks_scored  boundary_fours  \
# ...

# %%
df['player_name'].str.split(pat = '(')
# Out:
# 0      [DG Bradman , AUS)]
# 1        [HC Brook , ENG)]
# 2        [AC Voges , AUS)]
# 3       [RG Pollock , SA)]
# 4       [GA Headley , WI)]
#               ...
# 61     [KD Walters , AUS)]
# 62    [GC Smith , ICC/SA)]
# 63    [WH Ponsford , AUS)]
# 64      [SJ McCabe , AUS)]
# 65     [DR Jardine , ENG)]
# Name: player_name, Length: 66, dtype: object

# %%
df['player'] = df['player_name'].str.split(pat = '(').str[0]

# %%
df.head()
# Out:
#         player_name  matches_played  innings_batted  not_outs  runs  \
# 0  DG Bradman (AUS)              52              80        10  6996
# 1    HC Brook (ENG)              12              20         1  1181
# 2    AC Voges (AUS)              20              31         7  1485
# 3   RG Pollock (SA)              23              41         4  2256
# 4   GA Headley (WI)              22              40         4  2190
#
#   highest_innings_score  batting_average balls_faced  batting_strike_rate  \
# 0                   334            99.94       9800+                58.60
# 1                   186            62.15        1287                91.76
# 2                  269*            61.87        2667                55.68
# 3                   274            60.97       1707+                54.48
# 4                  270*            60.83        416+                56.00
#
#    hundereds_scored  fifties_scored  ducks_scored  boundary_fours  \
# ...

# %%
df['country'] = df['player_name'].str.split(pat = '(').str[1]

# %%
df.head()
# Out:
#         player_name  matches_played  innings_batted  not_outs  runs  \
# 0  DG Bradman (AUS)              52              80        10  6996
# 1    HC Brook (ENG)              12              20         1  1181
# 2    AC Voges (AUS)              20              31         7  1485
# 3   RG Pollock (SA)              23              41         4  2256
# 4   GA Headley (WI)              22              40         4  2190
#
#   highest_innings_score  batting_average balls_faced  batting_strike_rate  \
# 0                   334            99.94       9800+                58.60
# 1                   186            62.15        1287                91.76
# 2                  269*            61.87        2667                55.68
# 3                   274            60.97       1707+                54.48
# 4                  270*            60.83        416+                56.00
#
#    hundereds_scored  fifties_scored  ducks_scored  boundary_fours  \
# ...

# %%
df['country'].str.split(pat = ')')
# Out:
# 0        [AUS, ]
# 1        [ENG, ]
# 2        [AUS, ]
# 3         [SA, ]
# 4         [WI, ]
#          ...
# 61       [AUS, ]
# 62    [ICC/SA, ]
# 63       [AUS, ]
# 64       [AUS, ]
# 65       [ENG, ]
# Name: country, Length: 66, dtype: object

# %%
df['country'] = df['country'].str.split(pat = ')').str[0]

# %%
df.head()
# Out:
#         player_name  matches_played  innings_batted  not_outs  runs  \
# 0  DG Bradman (AUS)              52              80        10  6996
# 1    HC Brook (ENG)              12              20         1  1181
# 2    AC Voges (AUS)              20              31         7  1485
# 3   RG Pollock (SA)              23              41         4  2256
# 4   GA Headley (WI)              22              40         4  2190
#
#   highest_innings_score  batting_average balls_faced  batting_strike_rate  \
# 0                   334            99.94       9800+                58.60
# 1                   186            62.15        1287                91.76
# 2                  269*            61.87        2667                55.68
# 3                   274            60.97       1707+                54.48
# 4                  270*            60.83        416+                56.00
#
#    hundereds_scored  fifties_scored  ducks_scored  boundary_fours  \
# ...

# %%
df.drop(['player_name'], axis = 1)
# Out:
#     matches_played  innings_batted  not_outs  runs highest_innings_score  \
# 0               52              80        10  6996                   334
# 1               12              20         1  1181                   186
# 2               20              31         7  1485                  269*
# 3               23              41         4  2256                   274
# 4               22              40         4  2190                  270*
# ..             ...             ...       ...   ...                   ...
# 61              74             125        14  5357                   250
# 62             117             205        13  9265                   277
# 63              29              48         4  2122                   266
# 64              39              62         5  2748                   232
# 65              22              33         6  1296                   127
#
#     batting_average balls_faced  batting_strike_rate  hundereds_scored  \
# ...

# %%
df.dtypes
# Out:
# player_name               object
# matches_played             int64
# innings_batted             int64
# not_outs                   int64
# runs                       int64
# highest_innings_score     object
# batting_average          float64
# balls_faced               object
# batting_strike_rate      float64
# hundereds_scored           int64
# fifties_scored             int64
# ducks_scored               int64
# boundary_fours             int64
# boundary_sixes             int64
# launch_year               object
# final_year                object
# player                    object
# country                   object
# dtype: object

# %%
df['balls_faced']=df['balls_faced'].str.split(pat = '+').str[0]

# %%
df['highest_innings_score']=df['balls_faced'].str.split(pat = '*').str[0]

# %%
df.head()
# Out:
#         player_name  matches_played  innings_batted  not_outs  runs  \
# 0  DG Bradman (AUS)              52              80        10  6996
# 1    HC Brook (ENG)              12              20         1  1181
# 2    AC Voges (AUS)              20              31         7  1485
# 3   RG Pollock (SA)              23              41         4  2256
# 4   GA Headley (WI)              22              40         4  2190
#
#   highest_innings_score  batting_average balls_faced  batting_strike_rate  \
# 0                  9800            99.94        9800                58.60
# 1                  1287            62.15        1287                91.76
# 2                  2667            61.87        2667                55.68
# 3                  1707            60.97        1707                54.48
# 4                   416            60.83         416                56.00
#
#    hundereds_scored  fifties_scored  ducks_scored  boundary_fours  \
# ...

# %%
df = df.astype({'launch_year':'int','final_year':'int'})

# %%
df.dtypes
# Out:
# player_name               object
# matches_played             int64
# innings_batted             int64
# not_outs                   int64
# runs                       int64
# highest_innings_score     object
# batting_average          float64
# balls_faced               object
# batting_strike_rate      float64
# hundereds_scored           int64
# fifties_scored             int64
# ducks_scored               int64
# boundary_fours             int64
# boundary_sixes             int64
# launch_year                int32
# final_year                 int32
# player                    object
# country                   object
# dtype: object

# %%
df.isnull().sum()
# Out:
# player_name              0
# matches_played           0
# innings_batted           0
# not_outs                 0
# runs                     0
# highest_innings_score    3
# batting_average          0
# balls_faced              3
# batting_strike_rate      0
# hundereds_scored         0
# fifties_scored           0
# ducks_scored             0
# boundary_fours           0
# boundary_sixes           0
# launch_year              0
# final_year               0
# player                   0
# country                  0
# dtype: int64

# %%
df[df['highest_innings_score'].isna() == 1]
# Out:
#              player_name  matches_played  innings_batted  not_outs  runs  \
# 9         ED Weekes (WI)              48              81         5  4455
# 16       CL Walcott (WI)              44              74         7  3798
# 58  Hon.FS Jackson (ENG)              20              33         4  1415
#
#    highest_innings_score  batting_average balls_faced  batting_strike_rate  \
# 9                    NaN            58.61         NaN                  0.0
# 16                   NaN            56.68         NaN                  0.0
# 58                   NaN            48.79         NaN                  0.0
#
#     hundereds_scored  fifties_scored  ducks_scored  boundary_fours  \
# 9                 15              19             6             258
# 16                15              14             1             107
# 58                 5               6             3              51
#
#     boundary_sixes  launch_year  final_year           player country
# ...

# %%
df['highest_innings_score'] = df['highest_innings_score'].fillna(0)

# %%
df['balls_faced'] = df['balls_faced'].fillna(0)

# %%
df = df.astype({'highest_innings_score':'int','balls_faced':'int'})

# %%
df.dtypes
# Out:
# player_name               object
# matches_played             int64
# innings_batted             int64
# not_outs                   int64
# runs                       int64
# highest_innings_score      int32
# batting_average          float64
# balls_faced                int32
# batting_strike_rate      float64
# hundereds_scored           int64
# fifties_scored             int64
# ducks_scored               int64
# boundary_fours             int64
# boundary_sixes             int64
# launch_year                int32
# final_year                 int32
# player                    object
# country                   object
# dtype: object

# %%
df['career_length'] = df['final_year'] - df['launch_year']

# %%
df.head()
# Out:
#         player_name  matches_played  innings_batted  not_outs  runs  \
# 0  DG Bradman (AUS)              52              80        10  6996
# 1    HC Brook (ENG)              12              20         1  1181
# 2    AC Voges (AUS)              20              31         7  1485
# 3   RG Pollock (SA)              23              41         4  2256
# 4   GA Headley (WI)              22              40         4  2190
#
#    highest_innings_score  batting_average  balls_faced  batting_strike_rate  \
# 0                   9800            99.94         9800                58.60
# 1                   1287            62.15         1287                91.76
# 2                   2667            61.87         2667                55.68
# 3                   1707            60.97         1707                54.48
# 4                    416            60.83          416                56.00
#
#    hundereds_scored  fifties_scored  ducks_scored  boundary_fours  \
# ...

# %%
#lets solve some questions

# %%
#Average career length of cricketrs

# %%
df['career_length'].mean()
# Out:
# 13.666666666666666

# %%
# calculate the average batting strike rate for players who played above 10 years

# %%
df[df['career_length']>10]['batting_strike_rate'].mean()
# Out:
# 48.14062499999999

# %%
#find number of cricketers who played before 1960

# %%
df[df['launch_year']<1960]['player'].count()
# Out:
# 25

# %%
#find the max highest innings score by country

# %%
df.groupby('country')['highest_innings_score'].max().to_frame('max_innings_score').reset_index().sort_values('max_innings_score',ascending = False)
# Out:
#     country  max_innings_score
# 2   ICC/IND              31258
# 6       IND              29437
# 4    ICC/SA              28903
# 11       WI              27396
# 0       AUS              27002
# 10       SL              22959
# 1       ENG              20762
# 5    ICC/WI              19753
# 8       PAK              19375
# 7        NZ              17006
# 3   ICC/PAK              16345
# 9        SA              16077
# 12      ZIM              10636

# %%
df.groupby('country')[['hundereds_scored','fifties_scored','boundary_sixes']].mean()
# Out:
#          hundereds_scored  fifties_scored  boundary_sixes
# country
# AUS             20.625000       28.375000       25.375000
# ENG             12.571429       21.357143       11.357143
# ICC/IND         29.500000       47.500000       56.000000
# ICC/PAK         25.000000       46.000000       48.000000
# ICC/SA          36.000000       48.000000       60.500000
# ICC/WI          34.000000       48.000000       88.000000
# IND             29.400000       35.200000       30.600000
# NZ              18.500000       22.000000       26.500000
# PAK             21.250000       28.000000       43.500000
# SA               9.800000       20.200000       20.400000
# SL              28.666667       44.000000       39.666667
# WI              17.300000       27.600000       21.500000
# ZIM             12.000000       27.000000       20.000000

# %%
import matplotlib.pyplot as plt

# %%
plt.bar(df['country'],df['batting_average'])
# Out:
# <BarContainer object of 66 artists>
